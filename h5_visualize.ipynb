# %%
import h5py

# %%
file_path = r'C:\Users\LEGION\Desktop\cad_project\Drawing2CAD\proj_log\my_exp_train\test_results\00017318_vec.h5'
file_path=r'C:\Users\LEGION\Desktop\cad_project\DeepCAD\data2\cad_vec\0000\00000659.h5'

with h5py.File(file_path, 'r') as f:
    print("Available datasets/groups:", list(f.keys()))
    # first_key = next(iter(f.keys()))
    # second_key = next(iter(f[first_key].keys()))
    # print(f"First key: {first_key}, Second key: {second_key}")
    # print(f[first_key][:])
    # print(f['gt_vec'][:])
    # print(f['out_vec'][:])
    print(f['vec'][:])
# Out:
# Available datasets/groups: ['vec']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32772\2517250260.py in <module>
#       8     # print(f"First key: {first_key}, Second key: {second_key}")
#       9     # print(f[first_key][:])
# ---> 10     print(f['gt_vec'][:])
#      11     print(f['out_vec'][:])
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# c:\Users\LEGION\anaconda3\envs\deepcad\lib\site-packages\h5py\_hl\group.py in __getitem__(self, name)
#     262                 raise ValueError("Invalid HDF5 object reference")
#     263         else:
# --> 264             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     265
#     266         otype = h5i.get_type(oid)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ...

# %%
data['gt_vec']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23828\1289801692.py in <module>
# ----> 1 data['gt_vec']
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# c:\Users\LEGION\anaconda3\envs\deepcad\lib\site-packages\h5py\_hl\group.py in __getitem__(self, name)
#     262                 raise ValueError("Invalid HDF5 object reference")
#     263         else:
# --> 264             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     265
#     266         otype = h5i.get_type(oid)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5o.pyx in h5py.h5o.open()
#
# ValueError: Not a location (invalid object ID)
