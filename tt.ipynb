# %%
import numpy as np

# %%
t=np.load(r'C:\Users\LEGION\Desktop\cad_project\DeepCAD\data2\svg_vec\0014\00140033.npy')

# %%
t[300]
# Out:
# array([ 3.,  0., -1., -1., -1., -1., -1., -1., -1., -1.])
